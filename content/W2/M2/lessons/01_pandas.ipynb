# %% [markdown]
# # Learn Pandas

# %% [markdown]
# **Pandas** provides fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It is built on top of **NumPy**, which is built on top of **C**. So, it is really fast.

# %% [markdown]
# Data can be loaded into a Pandas DataFrame from various sources and different formats:
#
# 1. **Databases**: relational (SQL) and unstructured (NoSQL)
# 2. **Surveys**: Google Forms, SurveyMonkey
# 3. **APIs**: Social Media Platforms, Open Street Maps, Flights, ..etc.
# 4. **Web Scraping**: BeautifulSoup, Scrapy, Selenium
# 5. **Raw Files**: csv, excel, txt, json, xml, pdf, ..etc.

# %% [markdown]
# ## Activity 1
#
# - **In Class:** we go through the [**Getting started tutorials**](https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html) from the official Pandas' documentation pages.
# - **Estimated time**: 40 minutes + 40 minutes = 1:20 hours

# %% [markdown]
# ## Activity 2
#
# - **In Class**: we go through the [SQL to Pandas](https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html) for CS students since they have seen SQL before.
# - **Estimated time**: 20 minutes.

# %% [markdown]
# ## Assingment
#
# ### 1. Reading
#
# **Task**: read the Pandas documentation pages (estimated time: ~3 hours):
#
# 1. [10 Minutes to Pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
# 2. [Intro to data structures](https://pandas.pydata.org/docs/user_guide/dsintro.html)
#    - When you reach DataFrame, read the first part, you can safely jump to: [Column Selection, Addition, and Deletion](https://pandas.pydata.org/docs/user_guide/dsintro.html#column-selection-addition-deletion).
#
# If you already know the basics, you can read the in-depth: [Essential basic functionality](https://pandas.pydata.org/docs/user_guide/basics.html). After which, you should be able to answer the following questions:
#
# - Why *Iteration* in Pandas is not a good idea?
# - How to apply `datetime` methods, on a Series?
# - How to apply string methods, on a Series?
# - How to select columns based on `dtype`?
#
# ### 2. Bookmarks
#
# **Task**: Bookmark the following references in your browswer. These are **Handy References** to use while working with Pandas, presented in three different ways:
#
# - [Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Methods' Mind Map](https://xmind.ai/share/ugVH30g4)
# - [Pandas Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html)
